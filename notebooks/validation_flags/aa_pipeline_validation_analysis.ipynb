# %%
from riot_na.data.model import Scheme
from pathlib import Path
import pandas as pd
from IPython.display import Markdown
from notebooks.utils import base64_decode_series, calculate_validation_flags_summary

# %% [markdown]
# # Validation flags results - Amino acids, all species

# %%
RESULTS_DIR = Path().absolute().parent.parent / "results" / "mouse_database_aa"

# %%
for scheme in Scheme:
    path = RESULTS_DIR / f"ngs_sample_clean_{scheme.value}.csv"
    df = pd.read_csv(
        path,
        index_col=0,
        engine="pyarrow",
        usecols=["sequence_header", "v_call", "productive", "additional_validation_flags"],
    )
    df = base64_decode_series(df, "additional_validation_flags")
    display(Markdown(f"## {scheme.upper()}"))
    display(calculate_validation_flags_summary(df))
    display(Markdown("---"))
# Out:
# ## KABAT
#                                             False      True
# regions_aa_in_aligned_sequence_aa             NaN  402762.0
# locus_as_in_v_gene                            NaN  402770.0
# v_gene_alignment_aa                           NaN  402770.0
# j_gene_alignment_aa                           NaN  402770.0
# no_negative_offsets_inside_v_alignment_aa   357.0  402413.0
# no_negative_offsets_inside_j_alignment_aa     NaN  402770.0
# consecutive_offsets_aa                        NaN  402770.0
# no_empty_cdr3_aa                           1448.0  401322.0
# primary_sequence_in_sequence_alignment_aa     NaN  402770.0
# no_insertion_next_to_deletion_aa              NaN  402770.0
# insertions_in_correct_places               2952.0  399818.0
# correct_fwr1_aa_offsets                      88.0  398626.0
# correct_cdr1_aa_offsets                      67.0  399722.0
# correct_fwr2_aa_offsets                      50.0  401270.0
# correct_cdr2_aa_offsets                      46.0  401959.0
# correct_fwr3_aa_offsets                      44.0  402151.0
# correct_cdr3_aa_offsets                      58.0  401264.0
# correct_fwr4_aa_offsets                      61.0  401242.0
# no_empty_fwr1_aa_in_v                      4056.0  398714.0
# no_empty_cdr1_aa_in_v                      2981.0  399789.0
# no_empty_fwr2_aa_in_v                      1450.0  401320.0
# no_empty_cdr2_aa_in_v                       765.0  402005.0
# no_empty_fwr3_aa_in_v                       575.0  402195.0
# no_empty_fwr4_aa_in_j                      1467.0  401303.0
# ---
# ## CHOTHIA
#                                             False      True
# regions_aa_in_aligned_sequence_aa             NaN  402762.0
# locus_as_in_v_gene                            NaN  402770.0
# v_gene_alignment_aa                           NaN  402770.0
# j_gene_alignment_aa                           NaN  402770.0
# no_negative_offsets_inside_v_alignment_aa   399.0  402371.0
# no_negative_offsets_inside_j_alignment_aa     NaN  402770.0
# consecutive_offsets_aa                        NaN  402770.0
# no_empty_cdr3_aa                           1590.0  401180.0
# primary_sequence_in_sequence_alignment_aa     NaN  402770.0
# no_insertion_next_to_deletion_aa              NaN  402770.0
# insertions_in_correct_places               3824.0  398946.0
# correct_fwr1_aa_offsets                      88.0  398000.0
# correct_cdr1_aa_offsets                      69.0  399221.0
# correct_fwr2_aa_offsets                      57.0  401400.0
# correct_cdr2_aa_offsets                      46.0  401116.0
# correct_fwr3_aa_offsets                      47.0  402210.0
# correct_cdr3_aa_offsets                      58.0  401122.0
# correct_fwr4_aa_offsets                      61.0  401248.0
# no_empty_fwr1_aa_in_v                      4682.0  398088.0
# no_empty_cdr1_aa_in_v                      3480.0  399290.0
# no_empty_fwr2_aa_in_v                      1313.0  401457.0
# no_empty_cdr2_aa_in_v                      1608.0  401162.0
# no_empty_fwr3_aa_in_v                       513.0  402257.0
# no_empty_fwr4_aa_in_j                      1461.0  401309.0
# ---
# ## IMGT
#                                              False      True
# regions_aa_in_aligned_sequence_aa              NaN  402762.0
# locus_as_in_v_gene                             NaN  402770.0
# v_gene_alignment_aa                            NaN  402770.0
# j_gene_alignment_aa                            NaN  402770.0
# no_negative_offsets_inside_v_alignment_aa    427.0  402343.0
# no_negative_offsets_inside_j_alignment_aa      NaN  402770.0
# consecutive_offsets_aa                         NaN  402770.0
# no_empty_cdr3_aa                             722.0  402048.0
# primary_sequence_in_sequence_alignment_aa      NaN  402770.0
# no_insertion_next_to_deletion_aa               NaN  402770.0
# insertions_in_correct_places                1364.0  401406.0
# correct_fwr1_aa_offsets                       88.0  398027.0
# correct_cdr1_aa_offsets                       68.0  399345.0
# correct_fwr2_aa_offsets                       57.0  401341.0
# correct_cdr2_aa_offsets                       46.0  401200.0
# correct_fwr3_aa_offsets                       43.0  402167.0
# correct_cdr3_aa_offsets                       58.0  401990.0
# correct_fwr4_aa_offsets                       61.0  401242.0
# no_empty_fwr1_aa_in_v                       4655.0  398115.0
# no_empty_cdr1_aa_in_v                       3357.0  399413.0
# no_empty_fwr2_aa_in_v                       1372.0  401398.0
# no_empty_cdr2_aa_in_v                       1524.0  401246.0
# no_empty_fwr3_aa_in_v                        560.0  402210.0
# no_empty_fwr4_aa_in_j                       1467.0  401303.0
# conserved_C23_present                      10900.0  391870.0
# conserved_W41_present                       6232.0  396538.0
# conserved_C104_present                      4878.0  397892.0
# conserved_F118_light_present                2594.0  100409.0
# conserved_W118_heavy_present                5904.0  293863.0
# ---
# ## MARTIN
#                                             False      True
# regions_aa_in_aligned_sequence_aa             NaN  402762.0
# locus_as_in_v_gene                            NaN  402770.0
# v_gene_alignment_aa                           NaN  402770.0
# j_gene_alignment_aa                           NaN  402770.0
# no_negative_offsets_inside_v_alignment_aa   399.0  402371.0
# no_negative_offsets_inside_j_alignment_aa     NaN  402770.0
# consecutive_offsets_aa                        NaN  402770.0
# no_empty_cdr3_aa                           1590.0  401180.0
# primary_sequence_in_sequence_alignment_aa     NaN  402770.0
# no_insertion_next_to_deletion_aa              NaN  402770.0
# insertions_in_correct_places               2581.0  400189.0
# correct_fwr1_aa_offsets                      88.0  398000.0
# correct_cdr1_aa_offsets                      69.0  399221.0
# correct_fwr2_aa_offsets                      57.0  401400.0
# correct_cdr2_aa_offsets                      46.0  401116.0
# correct_fwr3_aa_offsets                      47.0  402210.0
# correct_cdr3_aa_offsets                      58.0  401122.0
# correct_fwr4_aa_offsets                      61.0  401248.0
# no_empty_fwr1_aa_in_v                      4682.0  398088.0
# no_empty_cdr1_aa_in_v                      3480.0  399290.0
# no_empty_fwr2_aa_in_v                      1313.0  401457.0
# no_empty_cdr2_aa_in_v                      1608.0  401162.0
# no_empty_fwr3_aa_in_v                       513.0  402257.0
# no_empty_fwr4_aa_in_j                      1461.0  401309.0
# ---
