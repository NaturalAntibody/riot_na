# %%
from riot_na.data.model import Scheme
from pathlib import Path
import pandas as pd
from IPython.display import Markdown
from notebooks.utils import base64_decode_series, calculate_validation_flags_summary

# %% [markdown]
# # Validation flags results - Nucleotides, human

# %%
RESULTS_DIR = Path().absolute().parent.parent / "results" / "mouse_database_nt"

# %%
for scheme in Scheme:
    path = RESULTS_DIR / f"ngs_sample_clean_{scheme.value}_human.csv"
    df = pd.read_csv(
        path,
        index_col=0,
        engine="pyarrow",
        usecols=["sequence_header", "v_call", "productive", "additional_validation_flags"],
    )
    df = base64_decode_series(df, "additional_validation_flags")
    display(Markdown(f"## {scheme.upper()}"))
    display(calculate_validation_flags_summary(df))
    display(Markdown("---"))
# Out:
# ## KABAT
#                                             False      True
# regions_in_aligned_sequence                   NaN  401346.0
# regions_aa_in_aligned_sequence_aa             NaN  401346.0
# translated_regions_in_aligned_sequence_aa     NaN  401346.0
# correct_vj_in_frame                           NaN  401346.0
# cdr3_in_junction                              NaN  399972.0
# locus_as_in_v_gene                            NaN  401346.0
# v_gene_alignment                              NaN  401346.0
# j_gene_alignment                              NaN  401346.0
# c_gene_alignment                              NaN  390859.0
# no_negative_offsets_inside_v_alignment      339.0  401007.0
# no_negative_offsets_inside_j_alignment        NaN  401346.0
# consecutive_offsets                           NaN  401346.0
# no_empty_cdr3                              1374.0  399972.0
# primary_sequence_in_sequence_alignment_aa     NaN  401346.0
# no_insertion_next_to_deletion_aa              1.0  401345.0
# insertions_in_correct_places               2831.0  398515.0
# correct_fwr1_offsets                          NaN  396595.0
# correct_cdr1_offsets                          NaN  397710.0
# correct_fwr2_offsets                          NaN  399207.0
# correct_cdr2_offsets                          NaN  399994.0
# correct_fwr3_offsets                          NaN  400968.0
# correct_cdr3_offsets                          NaN  399972.0
# correct_fwr4_offsets                          NaN  399866.0
# no_empty_fwr1_in_v                         4751.0  396595.0
# no_empty_cdr1_in_v                         3636.0  397710.0
# no_empty_fwr2_in_v                         2139.0  399207.0
# no_empty_cdr2_in_v                         1352.0  399994.0
# no_empty_fwr3_in_v                          378.0  400968.0
# no_empty_fwr4_in_j                         1480.0  399866.0
# ---
# ## CHOTHIA
#                                             False      True
# regions_in_aligned_sequence                   NaN  401346.0
# regions_aa_in_aligned_sequence_aa             NaN  401346.0
# translated_regions_in_aligned_sequence_aa     NaN  401346.0
# correct_vj_in_frame                           NaN  401346.0
# cdr3_in_junction                              NaN  399877.0
# locus_as_in_v_gene                            NaN  401346.0
# v_gene_alignment                              NaN  401346.0
# j_gene_alignment                              NaN  401346.0
# c_gene_alignment                              NaN  390859.0
# no_negative_offsets_inside_v_alignment      426.0  400920.0
# no_negative_offsets_inside_j_alignment        NaN  401346.0
# consecutive_offsets                           NaN  401346.0
# no_empty_cdr3                              1469.0  399877.0
# primary_sequence_in_sequence_alignment_aa     NaN  401346.0
# no_insertion_next_to_deletion_aa              NaN  401346.0
# insertions_in_correct_places               3820.0  397526.0
# correct_fwr1_offsets                          NaN  395939.0
# correct_cdr1_offsets                          NaN  397266.0
# correct_fwr2_offsets                          NaN  399329.0
# correct_cdr2_offsets                          NaN  399164.0
# correct_fwr3_offsets                          NaN  401036.0
# correct_cdr3_offsets                          NaN  399877.0
# correct_fwr4_offsets                          NaN  399874.0
# no_empty_fwr1_in_v                         5407.0  395939.0
# no_empty_cdr1_in_v                         4080.0  397266.0
# no_empty_fwr2_in_v                         2017.0  399329.0
# no_empty_cdr2_in_v                         2182.0  399164.0
# no_empty_fwr3_in_v                          310.0  401036.0
# no_empty_fwr4_in_j                         1472.0  399874.0
# ---
# ## IMGT
#                                              False      True
# regions_in_aligned_sequence                    NaN  401346.0
# regions_aa_in_aligned_sequence_aa              NaN  401346.0
# translated_regions_in_aligned_sequence_aa      NaN  401346.0
# correct_vj_in_frame                            NaN  401346.0
# cdr3_in_junction                               NaN  400616.0
# locus_as_in_v_gene                             NaN  401346.0
# v_gene_alignment                               NaN  401346.0
# j_gene_alignment                               NaN  401346.0
# c_gene_alignment                               NaN  390859.0
# no_negative_offsets_inside_v_alignment       430.0  400916.0
# no_negative_offsets_inside_j_alignment         NaN  401346.0
# consecutive_offsets                            NaN  401346.0
# no_empty_cdr3                                730.0  400616.0
# primary_sequence_in_sequence_alignment_aa      NaN  401346.0
# no_insertion_next_to_deletion_aa               NaN  401346.0
# insertions_in_correct_places                1646.0  399700.0
# correct_fwr1_offsets                           NaN  395967.0
# correct_cdr1_offsets                           NaN  397392.0
# correct_fwr2_offsets                           NaN  399286.0
# correct_cdr2_offsets                           NaN  399233.0
# correct_fwr3_offsets                           NaN  401015.0
# correct_cdr3_offsets                           NaN  400616.0
# correct_fwr4_offsets                           NaN  399866.0
# no_empty_fwr1_in_v                          5379.0  395967.0
# no_empty_cdr1_in_v                          3954.0  397392.0
# no_empty_fwr2_in_v                          2060.0  399286.0
# no_empty_cdr2_in_v                          2113.0  399233.0
# no_empty_fwr3_in_v                           331.0  401015.0
# no_empty_fwr4_in_j                          1480.0  399866.0
# conserved_C23_present                      11373.0  389973.0
# conserved_W41_present                       6772.0  394574.0
# conserved_C104_present                      4762.0  396584.0
# conserved_F118_light_present                2577.0  100733.0
# conserved_W118_heavy_present                5649.0  292387.0
# ---
# ## MARTIN
#                                             False      True
# regions_in_aligned_sequence                   NaN  401346.0
# regions_aa_in_aligned_sequence_aa             NaN  401346.0
# translated_regions_in_aligned_sequence_aa     NaN  401346.0
# correct_vj_in_frame                           NaN  401346.0
# cdr3_in_junction                              NaN  399877.0
# locus_as_in_v_gene                            NaN  401346.0
# v_gene_alignment                              NaN  401346.0
# j_gene_alignment                              NaN  401346.0
# c_gene_alignment                              NaN  390859.0
# no_negative_offsets_inside_v_alignment      426.0  400920.0
# no_negative_offsets_inside_j_alignment        NaN  401346.0
# consecutive_offsets                           NaN  401346.0
# no_empty_cdr3                              1469.0  399877.0
# primary_sequence_in_sequence_alignment_aa     NaN  401346.0
# no_insertion_next_to_deletion_aa              NaN  401346.0
# insertions_in_correct_places               2576.0  398770.0
# correct_fwr1_offsets                          NaN  395939.0
# correct_cdr1_offsets                          NaN  397266.0
# correct_fwr2_offsets                          NaN  399329.0
# correct_cdr2_offsets                          NaN  399164.0
# correct_fwr3_offsets                          NaN  401036.0
# correct_cdr3_offsets                          NaN  399877.0
# correct_fwr4_offsets                          NaN  399874.0
# no_empty_fwr1_in_v                         5407.0  395939.0
# no_empty_cdr1_in_v                         4080.0  397266.0
# no_empty_fwr2_in_v                         2017.0  399329.0
# no_empty_cdr2_in_v                         2182.0  399164.0
# no_empty_fwr3_in_v                          310.0  401036.0
# no_empty_fwr4_in_j                         1472.0  399874.0
# ---
