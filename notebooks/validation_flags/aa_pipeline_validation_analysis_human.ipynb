# %%
from riot_na.data.model import Scheme
from pathlib import Path
import pandas as pd
from IPython.display import Markdown
from notebooks.utils import base64_decode_series, calculate_validation_flags_summary

# %% [markdown]
# # Validation flags results - Amino acids, human

# %%
RESULTS_DIR = Path().absolute().parent.parent / "results" / "mouse_database_aa"

# %%
for scheme in Scheme:
    path = RESULTS_DIR / f"ngs_sample_clean_{scheme.value}_human.csv"
    df = pd.read_csv(
        path,
        index_col=0,
        engine="pyarrow",
        usecols=["sequence_header", "v_call", "productive", "additional_validation_flags"],
    )
    df = base64_decode_series(df, "additional_validation_flags")
    display(Markdown(f"## {scheme.upper()}"))
    display(calculate_validation_flags_summary(df))
    display(Markdown("---"))
# Out:
# ## KABAT
#                                             False      True
# regions_aa_in_aligned_sequence_aa             NaN  402714.0
# locus_as_in_v_gene                            NaN  402725.0
# v_gene_alignment_aa                           NaN  402725.0
# j_gene_alignment_aa                           NaN  402725.0
# no_negative_offsets_inside_v_alignment_aa   332.0  402393.0
# no_negative_offsets_inside_j_alignment_aa     NaN  402725.0
# consecutive_offsets_aa                        NaN  402725.0
# no_empty_cdr3_aa                           1459.0  401266.0
# primary_sequence_in_sequence_alignment_aa     NaN  402725.0
# no_insertion_next_to_deletion_aa              NaN  402725.0
# insertions_in_correct_places               2984.0  399741.0
# correct_fwr1_aa_offsets                      85.0  398583.0
# correct_cdr1_aa_offsets                      65.0  399702.0
# correct_fwr2_aa_offsets                      48.0  401263.0
# correct_cdr2_aa_offsets                      42.0  401952.0
# correct_fwr3_aa_offsets                      44.0  402159.0
# correct_cdr3_aa_offsets                      53.0  401213.0
# correct_fwr4_aa_offsets                      57.0  401185.0
# no_empty_fwr1_aa_in_v                      4057.0  398668.0
# no_empty_cdr1_aa_in_v                      2958.0  399767.0
# no_empty_fwr2_aa_in_v                      1414.0  401311.0
# no_empty_cdr2_aa_in_v                       731.0  401994.0
# no_empty_fwr3_aa_in_v                       522.0  402203.0
# no_empty_fwr4_aa_in_j                      1483.0  401242.0
# ---
# ## CHOTHIA
#                                             False      True
# regions_aa_in_aligned_sequence_aa             NaN  402714.0
# locus_as_in_v_gene                            NaN  402725.0
# v_gene_alignment_aa                           NaN  402725.0
# j_gene_alignment_aa                           NaN  402725.0
# no_negative_offsets_inside_v_alignment_aa   385.0  402340.0
# no_negative_offsets_inside_j_alignment_aa     NaN  402725.0
# consecutive_offsets_aa                        NaN  402725.0
# no_empty_cdr3_aa                           1589.0  401136.0
# primary_sequence_in_sequence_alignment_aa     NaN  402725.0
# no_insertion_next_to_deletion_aa              NaN  402725.0
# insertions_in_correct_places               3939.0  398786.0
# correct_fwr1_aa_offsets                      85.0  397956.0
# correct_cdr1_aa_offsets                      67.0  399198.0
# correct_fwr2_aa_offsets                      56.0  401397.0
# correct_cdr2_aa_offsets                      42.0  401120.0
# correct_fwr3_aa_offsets                      47.0  402212.0
# correct_cdr3_aa_offsets                      53.0  401083.0
# correct_fwr4_aa_offsets                      57.0  401191.0
# no_empty_fwr1_aa_in_v                      4684.0  398041.0
# no_empty_cdr1_aa_in_v                      3460.0  399265.0
# no_empty_fwr2_aa_in_v                      1272.0  401453.0
# no_empty_cdr2_aa_in_v                      1563.0  401162.0
# no_empty_fwr3_aa_in_v                       466.0  402259.0
# no_empty_fwr4_aa_in_j                      1477.0  401248.0
# ---
# ## IMGT
#                                              False      True
# regions_aa_in_aligned_sequence_aa              NaN  402714.0
# locus_as_in_v_gene                             NaN  402725.0
# v_gene_alignment_aa                            NaN  402725.0
# j_gene_alignment_aa                            NaN  402725.0
# no_negative_offsets_inside_v_alignment_aa    402.0  402323.0
# no_negative_offsets_inside_j_alignment_aa      NaN  402725.0
# consecutive_offsets_aa                         NaN  402725.0
# no_empty_cdr3_aa                             701.0  402024.0
# primary_sequence_in_sequence_alignment_aa      NaN  402725.0
# no_insertion_next_to_deletion_aa               NaN  402725.0
# insertions_in_correct_places                1408.0  401317.0
# correct_fwr1_aa_offsets                       85.0  397983.0
# correct_cdr1_aa_offsets                       65.0  399320.0
# correct_fwr2_aa_offsets                       55.0  401333.0
# correct_cdr2_aa_offsets                       42.0  401202.0
# correct_fwr3_aa_offsets                       43.0  402172.0
# correct_cdr3_aa_offsets                       53.0  401971.0
# correct_fwr4_aa_offsets                       57.0  401185.0
# no_empty_fwr1_aa_in_v                       4657.0  398068.0
# no_empty_cdr1_aa_in_v                       3340.0  399385.0
# no_empty_fwr2_aa_in_v                       1337.0  401388.0
# no_empty_cdr2_aa_in_v                       1481.0  401244.0
# no_empty_fwr3_aa_in_v                        510.0  402215.0
# no_empty_fwr4_aa_in_j                       1483.0  401242.0
# conserved_C23_present                      10857.0  391868.0
# conserved_W41_present                       6184.0  396541.0
# conserved_C104_present                      4822.0  397903.0
# conserved_F118_light_present                2583.0  100410.0
# conserved_W118_heavy_present                5873.0  293859.0
# ---
# ## MARTIN
#                                             False      True
# regions_aa_in_aligned_sequence_aa             NaN  402714.0
# locus_as_in_v_gene                            NaN  402725.0
# v_gene_alignment_aa                           NaN  402725.0
# j_gene_alignment_aa                           NaN  402725.0
# no_negative_offsets_inside_v_alignment_aa   385.0  402340.0
# no_negative_offsets_inside_j_alignment_aa     NaN  402725.0
# consecutive_offsets_aa                        NaN  402725.0
# no_empty_cdr3_aa                           1589.0  401136.0
# primary_sequence_in_sequence_alignment_aa     NaN  402725.0
# no_insertion_next_to_deletion_aa              NaN  402725.0
# insertions_in_correct_places               2696.0  400029.0
# correct_fwr1_aa_offsets                      85.0  397956.0
# correct_cdr1_aa_offsets                      67.0  399198.0
# correct_fwr2_aa_offsets                      56.0  401397.0
# correct_cdr2_aa_offsets                      42.0  401120.0
# correct_fwr3_aa_offsets                      47.0  402212.0
# correct_cdr3_aa_offsets                      53.0  401083.0
# correct_fwr4_aa_offsets                      57.0  401191.0
# no_empty_fwr1_aa_in_v                      4684.0  398041.0
# no_empty_cdr1_aa_in_v                      3460.0  399265.0
# no_empty_fwr2_aa_in_v                      1272.0  401453.0
# no_empty_cdr2_aa_in_v                      1563.0  401162.0
# no_empty_fwr3_aa_in_v                       466.0  402259.0
# no_empty_fwr4_aa_in_j                      1477.0  401248.0
# ---
