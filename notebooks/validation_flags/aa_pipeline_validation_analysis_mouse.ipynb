# %%
from riot_na.data.model import Scheme
from pathlib import Path
import pandas as pd
from IPython.display import Markdown
from notebooks.utils import base64_decode_series, calculate_validation_flags_summary

# %% [markdown]
# # Validation flags results - Amino acids, mouse

# %%
RESULTS_DIR = Path().absolute().parent.parent / "results" / "mouse_database_aa"

# %%
for scheme in Scheme:
    path = RESULTS_DIR / f"ngs_sample_clean_{scheme.value}_mouse.csv"
    df = pd.read_csv(
        path,
        index_col=0,
        engine="pyarrow",
        usecols=["sequence_header", "v_call", "productive", "additional_validation_flags"],
    )
    df = base64_decode_series(df, "additional_validation_flags")
    display(Markdown(f"## {scheme.upper()}"))
    display(calculate_validation_flags_summary(df))
    display(Markdown("---"))
# Out:
# ## KABAT
#                                             False      True
# regions_aa_in_aligned_sequence_aa             NaN  402621.0
# locus_as_in_v_gene                            NaN  402637.0
# v_gene_alignment_aa                           NaN  402637.0
# j_gene_alignment_aa                           NaN  402637.0
# no_negative_offsets_inside_v_alignment_aa   439.0  402198.0
# no_negative_offsets_inside_j_alignment_aa     NaN  402637.0
# consecutive_offsets_aa                        NaN  402637.0
# no_empty_cdr3_aa                           1687.0  400950.0
# primary_sequence_in_sequence_alignment_aa     NaN  402637.0
# no_insertion_next_to_deletion_aa              NaN  402637.0
# insertions_in_correct_places               5772.0  396865.0
# correct_fwr1_aa_offsets                     111.0  398558.0
# correct_cdr1_aa_offsets                      74.0  399527.0
# correct_fwr2_aa_offsets                      61.0  401052.0
# correct_cdr2_aa_offsets                      54.0  401590.0
# correct_fwr3_aa_offsets                      51.0  401671.0
# correct_cdr3_aa_offsets                      70.0  400880.0
# correct_fwr4_aa_offsets                      77.0  400948.0
# no_empty_fwr1_aa_in_v                      3968.0  398669.0
# no_empty_cdr1_aa_in_v                      3036.0  399601.0
# no_empty_fwr2_aa_in_v                      1524.0  401113.0
# no_empty_cdr2_aa_in_v                       993.0  401644.0
# no_empty_fwr3_aa_in_v                       915.0  401722.0
# no_empty_fwr4_aa_in_j                      1612.0  401025.0
# ---
# ## CHOTHIA
#                                              False      True
# regions_aa_in_aligned_sequence_aa              NaN  402621.0
# locus_as_in_v_gene                             NaN  402637.0
# v_gene_alignment_aa                            NaN  402637.0
# j_gene_alignment_aa                            NaN  402637.0
# no_negative_offsets_inside_v_alignment_aa    468.0  402169.0
# no_negative_offsets_inside_j_alignment_aa      NaN  402637.0
# consecutive_offsets_aa                         NaN  402637.0
# no_empty_cdr3_aa                            1872.0  400765.0
# primary_sequence_in_sequence_alignment_aa      NaN  402637.0
# no_insertion_next_to_deletion_aa               NaN  402637.0
# insertions_in_correct_places               15228.0  387409.0
# correct_fwr1_aa_offsets                      111.0  397806.0
# correct_cdr1_aa_offsets                       78.0  399040.0
# correct_fwr2_aa_offsets                       64.0  401198.0
# correct_cdr2_aa_offsets                       54.0  400667.0
# correct_fwr3_aa_offsets                       56.0  401763.0
# correct_cdr3_aa_offsets                       69.0  400696.0
# correct_fwr4_aa_offsets                       77.0  400948.0
# no_empty_fwr1_aa_in_v                       4720.0  397917.0
# no_empty_cdr1_aa_in_v                       3519.0  399118.0
# no_empty_fwr2_aa_in_v                       1375.0  401262.0
# no_empty_cdr2_aa_in_v                       1916.0  400721.0
# no_empty_fwr3_aa_in_v                        818.0  401819.0
# no_empty_fwr4_aa_in_j                       1612.0  401025.0
# ---
# ## IMGT
#                                              False      True
# regions_aa_in_aligned_sequence_aa              NaN  402621.0
# locus_as_in_v_gene                             NaN  402637.0
# v_gene_alignment_aa                            NaN  402637.0
# j_gene_alignment_aa                            NaN  402637.0
# no_negative_offsets_inside_v_alignment_aa    507.0  402130.0
# no_negative_offsets_inside_j_alignment_aa      NaN  402637.0
# consecutive_offsets_aa                         NaN  402637.0
# no_empty_cdr3_aa                            1071.0  401566.0
# primary_sequence_in_sequence_alignment_aa      NaN  402637.0
# no_insertion_next_to_deletion_aa               NaN  402637.0
# insertions_in_correct_places               13277.0  389360.0
# correct_fwr1_aa_offsets                      111.0  397847.0
# correct_cdr1_aa_offsets                       77.0  399158.0
# correct_fwr2_aa_offsets                       60.0  401127.0
# correct_cdr2_aa_offsets                       54.0  400769.0
# correct_fwr3_aa_offsets                       51.0  401684.0
# correct_cdr3_aa_offsets                       71.0  401495.0
# correct_fwr4_aa_offsets                       77.0  400948.0
# no_empty_fwr1_aa_in_v                       4679.0  397958.0
# no_empty_cdr1_aa_in_v                       3402.0  399235.0
# no_empty_fwr2_aa_in_v                       1450.0  401187.0
# no_empty_cdr2_aa_in_v                       1814.0  400823.0
# no_empty_fwr3_aa_in_v                        902.0  401735.0
# no_empty_fwr4_aa_in_j                       1612.0  401025.0
# conserved_C23_present                      11195.0  391442.0
# conserved_W41_present                       6390.0  396247.0
# conserved_C104_present                      5370.0  397267.0
# conserved_F118_light_present                2618.0  100024.0
# conserved_W118_heavy_present                6365.0  293630.0
# ---
# ## MARTIN
#                                              False      True
# regions_aa_in_aligned_sequence_aa              NaN  402621.0
# locus_as_in_v_gene                             NaN  402637.0
# v_gene_alignment_aa                            NaN  402637.0
# j_gene_alignment_aa                            NaN  402637.0
# no_negative_offsets_inside_v_alignment_aa    468.0  402169.0
# no_negative_offsets_inside_j_alignment_aa      NaN  402637.0
# consecutive_offsets_aa                         NaN  402637.0
# no_empty_cdr3_aa                            1871.0  400766.0
# primary_sequence_in_sequence_alignment_aa      NaN  402637.0
# no_insertion_next_to_deletion_aa               NaN  402637.0
# insertions_in_correct_places               15205.0  387432.0
# correct_fwr1_aa_offsets                      111.0  397806.0
# correct_cdr1_aa_offsets                       78.0  399040.0
# correct_fwr2_aa_offsets                       64.0  401198.0
# correct_cdr2_aa_offsets                       54.0  400667.0
# correct_fwr3_aa_offsets                       56.0  401763.0
# correct_cdr3_aa_offsets                       69.0  400697.0
# correct_fwr4_aa_offsets                       77.0  400948.0
# no_empty_fwr1_aa_in_v                       4720.0  397917.0
# no_empty_cdr1_aa_in_v                       3519.0  399118.0
# no_empty_fwr2_aa_in_v                       1375.0  401262.0
# no_empty_cdr2_aa_in_v                       1916.0  400721.0
# no_empty_fwr3_aa_in_v                        818.0  401819.0
# no_empty_fwr4_aa_in_j                       1612.0  401025.0
# ---
