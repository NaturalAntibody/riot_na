# %% [markdown]
# # Prefiltering grid search - D genes

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import *
from pathlib import Path
import pandas as pd

# %%
RESULTS_PATH = Path("/home/bartosz/Documents/riot/results/")

# %%
ngs_skbio = pd.read_csv("data/skbio_stratified_ngs_alignment_d.csv", index_col=0)
print(f"Number of sequences with evalue more than 0.001: {ngs_skbio[ngs_skbio['e_value'] > 0.001].shape[0]} / {ngs_skbio.shape[0]}")
ngs_skbio["target_id"] = ngs_skbio.apply(lambda row: (row["target_id"], row["rev_comp"]), axis=1)
ground_truth_df = ngs_skbio[["target_id"]]
# Out:
# Number of sequences with evalue more than 0.001: 217608 / 332692

# %% [markdown]
# ## Top 5 genes

# %%
top_n = 5
PARAMS = ["top", "kmer_size", "distance_threshold", "modulo"]

# %%
results_dir = RESULTS_PATH / "skbio_stratified_ngs_alignment_grid_search_d_igh"
res_df = aggregate_grid_search_results(results_dir, PARAMS, top_n, ground_truth_df, with_rev_comp=True)
res_path = f"results/prefiltering_grid_search_top_{top_n}_no_trash_alignments_fixed_diagonal_stratified_ngs_j_igh.csv"
res_df.to_csv(res_path)
res_df.sort_values("match_percent", ascending=False).head(20)
# Out:
# 100%|██████████| 225/225 [03:41<00:00,  1.02it/s]
#      top  kmer_size  distance_threshold  modulo  match_percent
# 172    5          5                   3       1       0.992779
# 179    5          5                   5       1       0.991962
# 168    5          5                   3       2       0.990337
# 163    5          5                   7       1       0.990025
# 104    5          5                   5       2       0.989694
# 118    5          5                   7       2       0.988156
# 177    5          7                   3       1       0.987696
# 96     5          7                   5       1       0.987687
# 62     5          7                   7       1       0.987635
# 61     5          7                  11       1       0.987626
# 31     5          7                   9       1       0.987626
# 138    5          7                  13       1       0.987600
# 173    5          7                  15       1       0.987583
# 125    5          7                  19       1       0.987574
# 117    5          7                  17       1       0.987574
# 115    5          5                   9       2       0.986966
# 191    5          5                  11       2       0.986419
# 35     5          5                   9       1       0.986054
# 193    5          5                  13       2       0.985306
# 5      5          5                  11       1       0.984724
