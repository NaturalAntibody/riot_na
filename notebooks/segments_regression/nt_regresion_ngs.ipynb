# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
DATA_PATH = Path(".") / "../../data"
RESULTS_PATH = Path(".") / "../../results"
RESULTS_PATH.mkdir(parents=True, exist_ok=True)

# %%
ngs_ground_truth_path = DATA_PATH / "ngs_stratified" / "ngs_sample_human_ground_truth_2_2_2.csv"
regression_results_path = RESULTS_PATH / "ngs_stratified" / "ngs_sample_human_regresion_results.csv"
ngs_input_path = DATA_PATH / "ngs_stratified" / "ngs_sample_human_nt.fasta"

# %%
from riot_na.api.api_mp import run_on_file_mp
from riot_na.api.api_mp import GENE_DB_DIR, InputType, Organism

run_on_file_mp(
    db_dir=GENE_DB_DIR,
    input_fasta_path=ngs_input_path,
    result_path=regression_results_path,
    input_type=InputType.NT,
    allowed_species=[Organism.HOMO_SAPIENS],
    extend_alignment=False,
    n_processes=8,
)
# Out:
# 100%|██████████| 392857/392857 [05:31<00:00, 1186.82it/s]

# %%
from notebooks.utils import base64_decode_series, validation_flags_comparison
import pandas as pd

new_df = pd.read_csv(regression_results_path, index_col=0, engine="pyarrow")
new_df_flags = base64_decode_series(new_df, "additional_validation_flags")
print(len(new_df_flags))

old_df = pd.read_csv(ngs_ground_truth_path, index_col=0, engine="pyarrow") 
old_df_flags = base64_decode_series(old_df, "additional_validation_flags")
print(len(old_df_flags))

validation_flags_comparison(old_df_flags, new_df_flags)
# Out:
# 364564
# 366284
#                                            False_old  False_new  \
# regions_in_aligned_sequence                      0.0       57.0
# regions_aa_in_aligned_sequence_aa                0.0        0.0
# translated_regions_in_aligned_sequence_aa    12594.0      143.0
# correct_vj_in_frame                              0.0        0.0
# cdr3_in_junction                                 0.0        0.0
# locus_as_in_v_gene                               0.0        0.0
# v_gene_alignment                                 0.0        0.0
# j_gene_alignment                                 0.0        0.0
# c_gene_alignment                                 0.0        0.0
# no_negative_offsets_inside_v_alignment         413.0      560.0
# no_negative_offsets_inside_j_alignment           0.0        0.0
# consecutive_offsets                              0.0        0.0
# no_empty_cdr3                                 1331.0      912.0
# primary_sequence_in_sequence_alignment_aa    12594.0      143.0
# no_insertion_next_to_deletion_aa                 0.0        0.0
# insertions_in_correct_places                   903.0      909.0
# correct_fwr1_offsets                             0.0        0.0
# correct_cdr1_offsets                             0.0        0.0
# correct_fwr2_offsets                             0.0        0.0
# correct_cdr2_offsets                             0.0        0.0
# correct_fwr3_offsets                             0.0        0.0
# correct_cdr3_offsets                             0.0        0.0
# correct_fwr4_offsets                             0.0        0.0
# no_empty_fwr1_in_v                            2715.0     2711.0
# no_empty_cdr1_in_v                            2057.0     1993.0
# no_empty_fwr2_in_v                             739.0      688.0
# no_empty_cdr2_in_v                            1183.0     1099.0
# no_empty_fwr3_in_v                             869.0      814.0
# no_empty_fwr4_in_j                            1563.0      748.0
# conserved_C23_present                         8167.0     8166.0
# conserved_W41_present                         4600.0     4599.0
# conserved_C104_present                        4624.0     4619.0
# conserved_W118_heavy_present                  5241.0     5009.0
# conserved_F118_light_present                  2495.0     2469.0
# productive                                       0.0        0.0
# complete_vdj                                  4253.0     3448.0
#
#                                            False_old-new  True_old  True_new  \
# regions_in_aligned_sequence                        -57.0  328601.0  328544.0
# regions_aa_in_aligned_sequence_aa                    0.0  328504.0  328522.0
# translated_regions_in_aligned_sequence_aa        12451.0  316007.0  328458.0
# correct_vj_in_frame                                  0.0  328601.0  328601.0
# cdr3_in_junction                                     0.0  327251.0  327653.0
# locus_as_in_v_gene                                   0.0  328601.0  328601.0
# v_gene_alignment                                     0.0  328601.0  328601.0
# j_gene_alignment                                     0.0  328601.0  328601.0
# c_gene_alignment                                     0.0  322155.0  322155.0
# no_negative_offsets_inside_v_alignment            -147.0  328188.0  328041.0
# no_negative_offsets_inside_j_alignment               0.0  328601.0  328601.0
# consecutive_offsets                                  0.0  328601.0  328601.0
# no_empty_cdr3                                      419.0  327270.0  327689.0
# primary_sequence_in_sequence_alignment_aa        12451.0  316007.0  328458.0
# no_insertion_next_to_deletion_aa                     0.0  328601.0  328601.0
# insertions_in_correct_places                        -6.0  327698.0  327692.0
# correct_fwr1_offsets                                 0.0  325886.0  325890.0
# correct_cdr1_offsets                                 0.0  326544.0  326608.0
# correct_fwr2_offsets                                 0.0  327862.0  327913.0
# correct_cdr2_offsets                                 0.0  327418.0  327502.0
# correct_fwr3_offsets                                 0.0  327732.0  327787.0
# correct_cdr3_offsets                                 0.0  327270.0  327689.0
# correct_fwr4_offsets                                 0.0  327038.0  327853.0
# no_empty_fwr1_in_v                                   4.0  325886.0  325890.0
# no_empty_cdr1_in_v                                  64.0  326544.0  326608.0
# no_empty_fwr2_in_v                                  51.0  327862.0  327913.0
# no_empty_cdr2_in_v                                  84.0  327418.0  327502.0
# no_empty_fwr3_in_v                                  55.0  327732.0  327787.0
# no_empty_fwr4_in_j                                 815.0  327038.0  327853.0
# conserved_C23_present                                1.0  320434.0  320435.0
# conserved_W41_present                                1.0  324001.0  324002.0
# conserved_C104_present                               5.0  323977.0  323982.0
# conserved_W118_heavy_present                       232.0  233414.0  233646.0
# conserved_F118_light_present                        26.0   87451.0   87477.0
# productive                                           0.0  328601.0  328601.0
# complete_vdj                                       805.0  324348.0  325153.0
#
#                                            True_old-new
# regions_in_aligned_sequence                        57.0
# regions_aa_in_aligned_sequence_aa                 -18.0
# translated_regions_in_aligned_sequence_aa      -12451.0
# correct_vj_in_frame                                 0.0
# cdr3_in_junction                                 -402.0
# locus_as_in_v_gene                                  0.0
# v_gene_alignment                                    0.0
# j_gene_alignment                                    0.0
# c_gene_alignment                                    0.0
# no_negative_offsets_inside_v_alignment            147.0
# no_negative_offsets_inside_j_alignment              0.0
# consecutive_offsets                                 0.0
# no_empty_cdr3                                    -419.0
# primary_sequence_in_sequence_alignment_aa      -12451.0
# no_insertion_next_to_deletion_aa                    0.0
# insertions_in_correct_places                        6.0
# correct_fwr1_offsets                               -4.0
# correct_cdr1_offsets                              -64.0
# correct_fwr2_offsets                              -51.0
# correct_cdr2_offsets                              -84.0
# correct_fwr3_offsets                              -55.0
# correct_cdr3_offsets                             -419.0
# correct_fwr4_offsets                             -815.0
# no_empty_fwr1_in_v                                 -4.0
# no_empty_cdr1_in_v                                -64.0
# no_empty_fwr2_in_v                                -51.0
# no_empty_cdr2_in_v                                -84.0
# no_empty_fwr3_in_v                                -55.0
# no_empty_fwr4_in_j                               -815.0
# conserved_C23_present                              -1.0
# conserved_W41_present                              -1.0
# conserved_C104_present                             -5.0
# conserved_W118_heavy_present                     -232.0
# conserved_F118_light_present                      -26.0
# productive                                          0.0
# complete_vdj                                     -805.0

# %%
# Merge dataframes
merged_df = old_df.merge(new_df, on='sequence_header', how='left', suffixes=('_x', '_y'))
merged_df = merged_df.fillna(False)[(merged_df['complete_vdj_x'] == True) & (merged_df['productive_x'] == True)]

# Define columns to exclude from comparison
exclude_cols = {"sequence_header", "additional_validation_flags", "exc", "c_alignment_start", "c_alignment_end"}

# Get columns to compare (vectorized approach)
compare_cols = [col for col in old_df.columns if col not in exclude_cols]

if compare_cols:
    # Vectorized comparison - do all columns at once
    x_cols = [f"{col}_x" for col in compare_cols]
    y_cols = [f"{col}_y" for col in compare_cols]
    
    # Create comparison dataframe in one operation
    comparison_data = merged_df[x_cols].values == merged_df[y_cols].values
    comparison_df = pd.DataFrame(
        comparison_data,
        columns=[f"{col}_comparison" for col in compare_cols],
        index=merged_df.index
    )
    
    # Concatenate once instead of multiple times
    merged_df = pd.concat([merged_df, comparison_df], axis=1)

# Get comparison columns and compute counts
comparison_columns = [f"{col}_comparison" for col in compare_cols]
if comparison_columns:
    # More efficient counting using value_counts with normalize=False
    comparison_counts = pd.DataFrame({
        col: merged_df[col].value_counts().reindex([False, True], fill_value=0)
        for col in comparison_columns
    }).T
    
    # Display results
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    display(comparison_counts)
# Out:
# /tmp/ipykernel_266378/768669873.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_df = merged_df.fillna(False)[(merged_df['complete_vdj_x'] == True) & (merged_df['productive_x'] == True)]
#                                        False   True
# sequence_comparison                   153272  171777
# numbering_scheme_comparison                0  325049
# locus_comparison                         210  324839
# stop_codon_comparison                    490  324559
# vj_in_frame_comparison                   211  324838
# v_frameshift_comparison                   22  325027
# j_frameshift_comparison                    4  325045
# productive_comparison                    701  324348
# rev_comp_comparison                       92  324957
# complete_vdj_comparison                  229  324820
# v_call_comparison                        223  324826
# d_call_comparison                        178  324871
# j_call_comparison                        210  324839
# c_call_comparison                        193  324856
# v_frame_comparison                        72  324977
# j_frame_comparison                       121  324928
# sequence_alignment_comparison            236  324813
# germline_alignment_comparison            244  324805
# sequence_aa_comparison                152737  172312
# sequence_alignment_aa_comparison       12944  312105
# germline_alignment_aa_comparison       12942  312107
# v_alignment_start_comparison             210  324839
# v_alignment_end_comparison               240  324809
# d_alignment_start_comparison             199  324850
# d_alignment_end_comparison               197  324852
# j_alignment_start_comparison             235  324814
# j_alignment_end_comparison               235  324814
# v_sequence_alignment_comparison          240  324809
# v_sequence_alignment_aa_comparison      7453  317596
# v_germline_alignment_comparison          244  324805
# v_germline_alignment_aa_comparison      7459  317590
# d_sequence_alignment_comparison          179  324870
# d_germline_alignment_comparison          179  324870
# j_sequence_alignment_comparison          210  324839
# j_sequence_alignment_aa_comparison      5910  319139
# j_germline_alignment_comparison          210  324839
# j_germline_alignment_aa_comparison      5910  319139
# c_sequence_alignment_comparison          193  324856
# c_germline_alignment_comparison          193  324856
# fwr1_comparison                          243  324806
# fwr1_aa_comparison                       273  324776
# cdr1_comparison                          222  324827
# cdr1_aa_comparison                       253  324796
# fwr2_comparison                          215  324834
# fwr2_aa_comparison                       255  324794
# cdr2_comparison                          127  324922
# cdr2_aa_comparison                       132  324917
# fwr3_comparison                          201  324848
# fwr3_aa_comparison                       211  324838
# cdr3_comparison                          214  324835
# cdr3_aa_comparison                       252  324797
# fwr4_comparison                          229  324820
# fwr4_aa_comparison                     12900  312149
# junction_comparison                      214  324835
# junction_aa_comparison                   265  324784
# junction_length_comparison               214  324835
# junction_aa_length_comparison            265  324784
# v_score_comparison                       243  324806
# d_score_comparison                       179  324870
# j_score_comparison                       210  324839
# c_score_comparison                       193  324856
# v_cigar_comparison                       243  324806
# d_cigar_comparison                       179  324870
# j_cigar_comparison                       210  324839
# c_cigar_comparison                       193  324856
# v_support_comparison                  153275  171774
# d_support_comparison                     180  324869
# j_support_comparison                     217  324832
# c_support_comparison                     193  324856
# v_identity_comparison                    243  324806
# d_identity_comparison                    177  324872
# j_identity_comparison                    210  324839
# c_identity_comparison                    193  324856
# v_sequence_start_comparison           153272  171777
# v_sequence_end_comparison             153273  171776
# d_sequence_start_comparison            75231  249818
# d_sequence_end_comparison              75231  249818
# j_sequence_start_comparison           153272  171777
# j_sequence_end_comparison             153272  171777
# c_sequence_start_comparison           149249  175800
# c_sequence_end_comparison             149249  175800
# v_germline_start_comparison              232  324817
# v_germline_end_comparison                220  324829
# d_germline_start_comparison              179  324870
# d_germline_end_comparison                178  324871
# j_germline_start_comparison              210  324839
# j_germline_end_comparison                210  324839
# c_germline_start_comparison              193  324856
# c_germline_end_comparison                193  324856
# fwr1_start_comparison                 153285  171764
# fwr1_end_comparison                   153285  171764
# cdr1_start_comparison                 153274  171775
# cdr1_end_comparison                   153274  171775
# fwr2_start_comparison                 153251  171798
# fwr2_end_comparison                   153251  171798
# cdr2_start_comparison                 153162  171887
# cdr2_end_comparison                   153162  171887
# fwr3_start_comparison                 153203  171846
# fwr3_end_comparison                   153203  171846
# cdr3_start_comparison                 153206  171843
# cdr3_end_comparison                   153206  171843
# fwr4_start_comparison                 153285  171764
# fwr4_end_comparison                   153285  171764
# sequence_aa_scheme_cigar_comparison      251  324798
# scheme_residue_mapping_comparison        251  324798
# positional_scheme_mapping_comparison     252  324797

# %% [markdown]
# Significant differences explanation:
# * sequence, sequence_aa - sequence is truncated to the segment ranges, input sequence is in the query_sequence field
# * v_support - although v_score is not different it depeneds on the len(sequence), so after truncation to the segment ranges it has a different value of len(query) variable so the result changes
# * regions _start, _end - regions ranges are related to the sequence, so it's moved by segment_start related to the query_sequence
